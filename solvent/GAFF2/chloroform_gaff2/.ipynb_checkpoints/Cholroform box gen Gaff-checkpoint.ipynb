# %%
# The molecular volume of octanol is 
Vm_cm3_per_mol = 80.2 # cm^3/mol
nm3_per_cm3 = (1.0e7)**3
Vm_nm3_per_mol = Vm_cm3_per_mol*nm3_per_cm3

# Avogadros number
N_A = 6.022e23  # (particles)  per mol = mol^{-1}

nparticles = 320
nparticles_in_moles = nparticles/N_A  # mol
V_in_nm3 = Vm_nm3_per_mol*nparticles_in_moles

box_length_in_nm = (V_in_nm3**(1/3))
print(f'box_length_in_nm for {nparticles} molecules of chlroform: {box_length_in_nm}')
# Out:
# box_length_in_nm for 320 molecules of chlroform: 3.492967395494109

# %%
import gromacs
import os
# Out:
# NOTE: Some configuration directories are not set up yet:
# 	/home/sgoold/.gromacswrapper
# 	/home/sgoold/.gromacswrapper/qscripts
# 	/home/sgoold/.gromacswrapper/templates
# NOTE: You can create the configuration file and directories with:
# 	>>> import gromacs
# 	>>> gromacs.config.setup()

# %%
os.system('gmx editconf -f chloroform_GMX.gro -box 3.5 3.5 3.5 -o chloroform_single.gro')
# Out:
# Note that major changes are planned in future for editconf, to improve usability and utility.
# Read 5 atoms
# Volume: 125 nm^3, corresponds to roughly 56200 electrons
# No velocities found
#     system size :  0.258  0.294  0.169 (nm)
#     center      :  0.000  0.000 -0.039 (nm)
#     box vectors :  5.000  5.000  5.000 (nm)
#     box angles  :  90.00  90.00  90.00 (degrees)
#     box volume  : 125.00               (nm^3)
#     shift       :  1.750  1.750  1.789 (nm)
# new center      :  1.750  1.750  1.750 (nm)
# new box vectors :  3.500  3.500  3.500 (nm)
# new box angles  :  90.00  90.00  90.00 (degrees)
# new box volume  :  42.88               (nm^3)
#                      :-) GROMACS - gmx editconf, 2020.4 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx editconf, version 2020.4
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/sgoold/git_repo/sampl9-voelzlab/logP/GAFF/solvent_boxes/chloroform
# Command line:
#   gmx editconf -f chloroform_GMX.gro -box 3.5 3.5 3.5 -o chloroform_single.gro
#
#
# GROMACS reminds you: "Heard a talk introducing a new language called Swift, from a guy named Wozniak, and it had nothing to do with Apple!" (Adam Cadien)
# 0

# %%
os.system('gmx insert-molecules -f chloroform_single.gro -ci chloroform_GMX.gro -box 3.5 3.5 3.5 -nmol 319 -try 20000 -o chloroform_to_be_equilibrated.gro')
# Out:
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary.
#
# NOTE: From version 5.0 gmx insert-molecules uses the Van der Waals radii
# from the source below. This means the results may be different
# compared to previous GROMACS versions.
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# A. Bondi
# van der Waals Volumes and Radii
# J. Phys. Chem. 68 (1964) pp. 441-451
# -------- -------- --- Thank You --- -------- --------
#                  :-) GROMACS - gmx insert-molecules, 2020.4 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx insert-molecules, version 2020.4
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/sgoold/git_repo/sampl9-voelzlab/logP/GAFF/solvent_boxes/chloroform
# Command line:
#   gmx insert-molecules -f chloroform_single.gro -ci chloroform_GMX.gro -box 3.5 3.5 3.5 -nmol 319 -try 20000 -o chloroform_to_be_equilibrated.gro
#
# Reading solute configuration
# Initialising inter-atomic distances...
# Using random seed -2044052095
# Try 1 success (now 10 atoms)!
# Try 2 success (now 15 atoms)!
# Try 3 success (now 20 atoms)!
# Try 4 success (now 25 atoms)!
# Try 5 success (now 30 atoms)!
# Try 7 success (now 35 atoms)!
# Try 8 success (now 40 atoms)!
# Try 9 success (now 45 atoms)!
# Try 10 success (now 50 atoms)!
# Try 11 success (now 55 atoms)!
# Try 12 success (now 60 atoms)!
# Try 13 success (now 65 atoms)!
# Try 14 success (now 70 atoms)!
# Try 15 success (now 75 atoms)!
# Try 16 success (now 80 atoms)!
# Try 17 success (now 85 atoms)!
# Try 19 success (now 90 atoms)!
# Try 20 success (now 95 atoms)!
# Try 21 success (now 100 atoms)!
# Try 22 success (now 105 atoms)!
# Try 23 success (now 110 atoms)!
# Try 25 success (now 115 atoms)!
# Try 27 success (now 120 atoms)!
# Try 28 success (now 125 atoms)!
# Try 29 success (now 130 atoms)!
# Try 30 success (now 135 atoms)!
# Try 31 success (now 140 atoms)!
# Try 32 success (now 145 atoms)!
# Try 33 success (now 150 atoms)!
# Try 34 success (now 155 atoms)!
# Try 35 success (now 160 atoms)!
# Try 36 success (now 165 atoms)!
# Try 38 success (now 170 atoms)!
# Try 39 success (now 175 atoms)!
# Try 40 success (now 180 atoms)!
# Try 41 success (now 185 atoms)!
# Try 42 success (now 190 atoms)!
# Try 43 success (now 195 atoms)!
# Try 45 success (now 200 atoms)!
# Try 46 success (now 205 atoms)!
# Try 47 success (now 210 atoms)!
# Try 48 success (now 215 atoms)!
# Try 49 success (now 220 atoms)!
# Try 50 success (now 225 atoms)!
# Try 51 success (now 230 atoms)!
# Try 53 success (now 235 atoms)!
# Try 54 success (now 240 atoms)!
# Try 55 success (now 245 atoms)!
# Try 58 success (now 250 atoms)!
# Try 59 success (now 255 atoms)!
# Try 61 success (now 260 atoms)!
# Try 62 success (now 265 atoms)!
# Try 63 success (now 270 atoms)!
# Try 64 success (now 275 atoms)!
# Try 65 success (now 280 atoms)!
# Try 66 success (now 285 atoms)!
# Try 67 success (now 290 atoms)!
# Try 68 success (now 295 atoms)!
# Try 69 success (now 300 atoms)!
# Try 70 success (now 305 atoms)!
# Try 72 success (now 310 atoms)!
# Try 73 success (now 315 atoms)!
# Try 74 success (now 320 atoms)!
# Try 75 success (now 325 atoms)!
# Try 77 success (now 330 atoms)!
# Try 78 success (now 335 atoms)!
# Try 79 success (now 340 atoms)!
# Try 82 success (now 345 atoms)!
# Try 83 success (now 350 atoms)!
# Try 86 success (now 355 atoms)!
# Try 87 success (now 360 atoms)!
# Try 89 success (now 365 atoms)!
# Try 90 success (now 370 atoms)!
# Try 91 success (now 375 atoms)!
# Try 92 success (now 380 atoms)!
# Try 93 success (now 385 atoms)!
# Try 94 success (now 390 atoms)!
# Try 95 success (now 395 atoms)!
# Try 96 success (now 400 atoms)!
# Try 97 success (now 405 atoms)!
# Try 100 success (now 410 atoms)!
# Try 101 success (now 415 atoms)!
# Try 103 success (now 420 atoms)!
# Try 105 success (now 425 atoms)!
# Try 106 success (now 430 atoms)!
# Try 107 success (now 435 atoms)!
# Try 108 success (now 440 atoms)!
# Try 109 success (now 445 atoms)!
# Try 110 success (now 450 atoms)!
# Try 111 success (now 455 atoms)!
# Try 112 success (now 460 atoms)!
# Try 116 success (now 465 atoms)!
# Try 118 success (now 470 atoms)!
# Try 119 success (now 475 atoms)!
# Try 120 success (now 480 atoms)!
# Try 121 success (now 485 atoms)!
# Try 123 success (now 490 atoms)!
# Try 125 success (now 495 atoms)!
# Try 128 success (now 500 atoms)!
# Try 129 success (now 505 atoms)!
# Try 130 success (now 510 atoms)!
# Try 132 success (now 515 atoms)!
# Try 138 success (now 520 atoms)!
# Try 140 success (now 525 atoms)!
# Try 141 success (now 530 atoms)!
# Try 143 success (now 535 atoms)!
# Try 146 success (now 540 atoms)!
# Try 147 success (now 545 atoms)!
# Try 150 success (now 550 atoms)!
# Try 153 success (now 555 atoms)!
# Try 154 success (now 560 atoms)!
# Try 155 success (now 565 atoms)!
# Try 159 success (now 570 atoms)!
# Try 160 success (now 575 atoms)!
# Try 161 success (now 580 atoms)!
# Try 164 success (now 585 atoms)!
# Try 166 success (now 590 atoms)!
# Try 167 success (now 595 atoms)!
# Try 168 success (now 600 atoms)!
# Try 172 success (now 605 atoms)!
# Try 176 success (now 610 atoms)!
# Try 178 success (now 615 atoms)!
# Try 180 success (now 620 atoms)!
# Try 181 success (now 625 atoms)!
# Try 185 success (now 630 atoms)!
# Try 187 success (now 635 atoms)!
# Try 189 success (now 640 atoms)!
# Try 190 success (now 645 atoms)!
# Try 199 success (now 650 atoms)!
# Try 202 success (now 655 atoms)!
# Try 205 success (now 660 atoms)!
# Try 206 success (now 665 atoms)!
# Try 208 success (now 670 atoms)!
# Try 210 success (now 675 atoms)!
# Try 212 success (now 680 atoms)!
# Try 215 success (now 685 atoms)!
# Try 216 success (now 690 atoms)!
# Try 217 success (now 695 atoms)!
# Try 219 success (now 700 atoms)!
# Try 223 success (now 705 atoms)!
# Try 227 success (now 710 atoms)!
# Try 228 success (now 715 atoms)!
# Try 239 success (now 720 atoms)!
# Try 242 success (now 725 atoms)!
# Try 244 success (now 730 atoms)!
# Try 245 success (now 735 atoms)!
# Try 247 success (now 740 atoms)!
# Try 249 success (now 745 atoms)!
# Try 252 success (now 750 atoms)!
# Try 257 success (now 755 atoms)!
# Try 258 success (now 760 atoms)!
# Try 260 success (now 765 atoms)!
# Try 261 success (now 770 atoms)!
# Try 262 success (now 775 atoms)!
# Try 271 success (now 780 atoms)!
# Try 278 success (now 785 atoms)!
# Try 287 success (now 790 atoms)!
# Try 292 success (now 795 atoms)!
# Try 295 success (now 800 atoms)!
# Try 297 success (now 805 atoms)!
# Try 299 success (now 810 atoms)!
# Try 300 success (now 815 atoms)!
# Try 301 success (now 820 atoms)!
# Try 303 success (now 825 atoms)!
# Try 305 success (now 830 atoms)!
# Try 309 success (now 835 atoms)!
# Try 314 success (now 840 atoms)!
# Try 321 success (now 845 atoms)!
# Try 322 success (now 850 atoms)!
# Try 327 success (now 855 atoms)!
# Try 328 success (now 860 atoms)!
# Try 332 success (now 865 atoms)!
# Try 336 success (now 870 atoms)!
# Try 339 success (now 875 atoms)!
# Try 343 success (now 880 atoms)!
# Try 345 success (now 885 atoms)!
# Try 346 success (now 890 atoms)!
# Try 353 success (now 895 atoms)!
# Try 365 success (now 900 atoms)!
# Try 366 success (now 905 atoms)!
# Try 896 success (now 1320 atoms)!
# Try 917 success (now 1325 atoms)!
# Try 943 success (now 1330 atoms)!
# Try 944 success (now 1335 atoms)!
# Try 948 success (now 1340 atoms)!
# Try 954 success (now 1345 atoms)!
# Try 955 success (now 1350 atoms)!
# Try 956 success (now 1355 atoms)!
# Try 957 success (now 1360 atoms)!
# Try 985 success (now 1365 atoms)!
# Try 1001 success (now 1370 atoms)!
# Try 1014 success (now 1375 atoms)!
# Try 1021 success (now 1380 atoms)!
# Try 1025 success (now 1385 atoms)!
# Try 1039 success (now 1390 atoms)!
# Try 1045 success (now 1395 atoms)!
# Try 1061 success (now 1400 atoms)!
# Try 1066 success (now 1405 atoms)!
# Try 1073 success (now 1410 atoms)!
# Try 1074 success (now 1415 atoms)!
# Try 1080 success (now 1420 atoms)!
# Try 1082 success (now 1425 atoms)!
# Try 1110 success (now 1430 atoms)!
# Try 1113 success (now 1435 atoms)!
# Try 1114 success (now 1440 atoms)!
# Try 1115 success (now 1445 atoms)!
# Try 1118 success (now 1450 atoms)!
# Try 1136 success (now 1455 atoms)!
# Try 1137 success (now 1460 atoms)!
# Try 1140 success (now 1465 atoms)!
# Try 1154 success (now 1470 atoms)!
# Try 1177 success (now 1475 atoms)!
# Try 1178 success (now 1480 atoms)!
# Try 1188 success (now 1485 atoms)!
# Try 1189 success (now 1490 atoms)!
# Try 1219 success (now 1495 atoms)!
# Try 1223 success (now 1500 atoms)!
# Try 1247 success (now 1505 atoms)!
# Try 1277 success (now 1510 atoms)!
# Try 1289 success (now 1515 atoms)!
# Try 1290 success (now 1520 atoms)!
# Try 1303 success (now 1525 atoms)!
# Try 1345 success (now 1530 atoms)!
# Try 1375 success (now 1535 atoms)!
# Try 1383 success (now 1540 atoms)!
# Try 1389 success (now 1545 atoms)!
# Try 1391 success (now 1550 atoms)!
# Try 1396 success (now 1555 atoms)!
# Try 1401 success (now 1560 atoms)!
# Try 1414 success (now 1565 atoms)!
# Try 1454 success (now 1570 atoms)!
# Try 1455 success (now 1575 atoms)!
# Try 1461 success (now 1580 atoms)!
# Try 1478 success (now 1585 atoms)!
# Try 1486 success (now 1590 atoms)!
# Try 1488 success (now 1595 atoms)!
# Try 1506 success (now 1600 atoms)!
#
# Added 319 molecules (out of 319 requested)
# Writing generated configuration to chloroform_to_be_equilibrated.gro
#
# Output configuration contains 1600 atoms in 320 residues
#
# GROMACS reminds you: "It's Calling Me to Break my Bonds, Again..." (Van der Graaf)
# 0

# %%
import sys
sys.path.append('../../../scripts')
from mdp_helpers import *

workdir = './work'
if not os.path.exists(workdir):
    os.mkdir(workdir)

    
import gromacs

# %%
## Minimize the system
em_mdpfile = f'{workdir}/em.mdp'
write_gromacs_min_mdp(em_mdpfile)

em_tprfile = f'{workdir}/em.tpr'
em_grofile = f'{workdir}/em.gro'
em_logfile = f'{workdir}/em.log'
em_trrfile = f'{workdir}/em.trr'
em_edrfile = f'{workdir}/em.edr'

input_grofile = 'chloroform_to_be_equilibrated.gro'
input_topfile = 'chloroform_GMX.top'

# %%
gromacs.grompp(f=em_mdpfile, c=input_grofile, p=input_topfile, o=em_tprfile)
gromacs.mdrun(v=True, s=em_tprfile, o=em_trrfile, c=em_grofile, e=em_edrfile, g=em_logfile)
# Out:
#                       :-) GROMACS - gmx grompp, 2020.4 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx grompp, version 2020.4
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/sgoold/git_repo/sampl9-voelzlab/logP/GAFF/solvent_boxes/chloroform
# Command line:
#   gmx grompp -f ./work/em.mdp -c chloroform_to_be_equilibrated.gro -p chloroform_GMX.top -o ./work/em.tpr
#
# Ignoring obsolete mdp entry 'ns_type'
# Setting the LD random seed to -1247356042
# Generated 6 of the 6 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 0.5
# Generated 6 of the 6 1-4 parameter combinations
# Excluding 3 bonded neighbours molecule type 'CHL'
# Number of degrees of freedom in T-Coupling group rest is 4797.00
# Estimate for the relative computational load of the PME mesh part: 0.22
#
# GROMACS reminds you: "Here, kitty, kitty..." (Erwin Schroedinger)
#
#                       :-) GROMACS - gmx mdrun, 2020.4 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx mdrun, version 2020.4
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/sgoold/git_repo/sampl9-voelzlab/logP/GAFF/solvent_boxes/chloroform
# Command line:
#   gmx mdrun -v -s ./work/em.tpr -o ./work/em.trr -c ./work/em.gro -e ./work/em.edr -g ./work/em.log
#
# Reading file ./work/em.tpr, VERSION 2020.4 (single precision)
# 1 GPU selected for this run.
# Mapping of GPU IDs to the 1 GPU task in the 1 rank on this node:
#   PP:0
# PP tasks will do (non-perturbed) short-ranged interactions on the GPU
# PP task will update and constrain coordinates on the CPU
# Using 1 MPI thread
#
# Non-default thread affinity set, disabling internal thread affinity
#
# Using 4 OpenMP threads
# Analysing residue names:
# There are:   320      Other residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 24x24x24, spacing 0.146 0.146 0.146
# This run will generate roughly 1 Mb of data
# Steepest Descents:
#    Tolerance (Fmax)   =  1.00000e+01
#    Number of steps    =       100000
# Step=    0, Dmax= 1.0e-02 nm, Epot=  3.07691e+05 Fmax= 4.03363e+05, atom= 29
# Step=    1, Dmax= 1.0e-02 nm, Epot=  2.26981e+05 Fmax= 1.76175e+05, atom= 29
# Step=    2, Dmax= 1.2e-02 nm, Epot=  1.52372e+05 Fmax= 7.19117e+04, atom= 133
# Step=    3, Dmax= 1.4e-02 nm, Epot=  9.13883e+04 Fmax= 2.82025e+04, atom= 924
# Step=    4, Dmax= 1.7e-02 nm, Epot=  5.11167e+04 Fmax= 1.26860e+04, atom= 1074
# Step=    5, Dmax= 2.1e-02 nm, Epot=  3.18561e+04 Fmax= 5.61779e+03, atom= 1304
# Step=    6, Dmax= 2.5e-02 nm, Epot=  2.14525e+04 Fmax= 8.99623e+03, atom= 1015
# Step=    7, Dmax= 3.0e-02 nm, Epot=  1.83834e+04 Fmax= 9.83483e+03, atom= 1015
# Step=    8, Dmax= 3.6e-02 nm, Epot=  1.60876e+04 Fmax= 1.38463e+04, atom= 1012
# Step=    9, Dmax= 4.3e-02 nm, Epot=  1.44718e+04 Fmax= 1.57740e+04, atom= 1012
# Step=   10, Dmax= 5.2e-02 nm, Epot=  1.32005e+04 Fmax= 1.71790e+04, atom= 1012
# Step=   11, Dmax= 6.2e-02 nm, Epot=  1.25857e+04 Fmax= 2.50192e+04, atom= 1012
# Step=   12, Dmax= 7.4e-02 nm, Epot=  1.14740e+04 Fmax= 2.11306e+04, atom= 1015
# Step=   51, Dmax= 1.4e-02 nm, Epot= -2.59446e+03 Fmax= 5.18915e+03, atom= 27
# Step=   52, Dmax= 1.7e-02 nm, Epot= -2.64484e+03 Fmax= 6.58912e+03, atom= 27
# Step=   53, Dmax= 2.1e-02 nm, Epot= -2.70451e+03 Fmax= 7.03658e+03, atom= 27
# Step=   55, Dmax= 1.2e-02 nm, Epot= -2.98045e+03 Fmax= 1.20934e+03, atom= 27
# Step=   56, Dmax= 1.5e-02 nm, Epot= -3.01673e+03 Fmax= 8.16970e+03, atom= 27
# Step=   57, Dmax= 1.8e-02 nm, Epot= -3.33928e+03 Fmax= 3.76673e+03, atom= 27
# Step=   59, Dmax= 1.1e-02 nm, Epot= -3.42495e+03 Fmax= 3.29625e+03, atom= 27
# Step=   60, Dmax= 1.3e-02 nm, Epot= -3.43875e+03 Fmax= 5.48234e+03, atom= 27
# Step=   61, Dmax= 1.5e-02 nm, Epot= -3.53695e+03 Fmax= 4.70593e+03, atom= 27
# Step=   63, Dmax= 9.3e-03 nm, Epot= -3.67961e+03 Fmax= 1.47360e+03, atom= 27
# Step=   64, Dmax= 1.1e-02 nm, Epot= -3.70060e+03 Fmax= 5.64506e+03, atom= 27
# Step=   65, Dmax= 1.3e-02 nm, Epot= -3.85963e+03 Fmax= 3.27004e+03, atom= 27
# Step=   67, Dmax= 8.0e-03 nm, Epot= -3.94131e+03 Fmax= 2.01502e+03, atom= 27
# Step=   68, Dmax= 9.6e-03 nm, Epot= -3.96266e+03 Fmax= 4.53155e+03, atom= 27
# Step=   69, Dmax= 1.2e-02 nm, Epot= -4.06160e+03 Fmax= 3.08355e+03, atom= 27
# Step=   71, Dmax= 6.9e-03 nm, Epot= -4.13991e+03 Fmax= 1.54276e+03, atom= 27
# Step=   72, Dmax= 8.3e-03 nm, Epot= -4.17794e+03 Fmax= 3.82485e+03, atom= 27
# Step=   73, Dmax= 1.0e-02 nm, Epot= -4.25922e+03 Fmax= 2.83677e+03, atom= 27
# Step=   75, Dmax= 6.0e-03 nm, Epot= -4.32835e+03 Fmax= 1.11348e+03, atom= 27
# Step=   76, Dmax= 7.2e-03 nm, Epot= -4.37726e+03 Fmax= 3.78191e+03, atom= 27
# Step=   77, Dmax= 8.6e-03 nm, Epot= -4.46376e+03 Fmax= 1.90831e+03, atom= 27
# Step=   79, Dmax= 5.2e-03 nm, Epot= -4.51375e+03 Fmax= 1.64103e+03, atom= 1337
# Step=   80, Dmax= 6.2e-03 nm, Epot= -4.55840e+03 Fmax= 2.27215e+03, atom= 27
# Step=   81, Dmax= 7.4e-03 nm, Epot= -4.59874e+03 Fmax= 2.85062e+03, atom= 1337
# Step=   82, Dmax= 8.9e-03 nm, Epot= -4.63921e+03 Fmax= 2.86007e+03, atom= 27
# Step=   83, Dmax= 1.1e-02 nm, Epot= -4.64418e+03 Fmax= 4.57786e+03, atom= 1337
# Step=   84, Dmax= 1.3e-02 nm, Epot= -4.70601e+03 Fmax= 3.73844e+03, atom= 1337
# Step=  394, Dmax= 3.6e-03 nm, Epot= -8.03016e+03 Fmax= 1.04898e+03, atom= 1337
# Step=  396, Dmax= 2.2e-03 nm, Epot= -8.03412e+03 Fmax= 4.10408e+02, atom= 1337
# Step=  397, Dmax= 2.6e-03 nm, Epot= -8.03739e+03 Fmax= 1.24657e+03, atom= 1337
# Step=  398, Dmax= 3.1e-03 nm, Epot= -8.04160e+03 Fmax= 8.52459e+02, atom= 1337
# Step=  399, Dmax= 3.8e-03 nm, Epot= -8.04205e+03 Fmax= 1.58207e+03, atom= 1337
# Step=  400, Dmax= 4.5e-03 nm, Epot= -8.04589e+03 Fmax= 1.43543e+03, atom= 1337
# Step=  402, Dmax= 2.7e-03 nm, Epot= -8.05146e+03 Fmax= 3.42570e+02, atom= 1337
# Step=  403, Dmax= 3.3e-03 nm, Epot= -8.05353e+03 Fmax= 1.90650e+03, atom= 1337
# Step=  404, Dmax= 3.9e-03 nm, Epot= -8.06165e+03 Fmax= 6.58836e+02, atom= 1337
# Step=  406, Dmax= 2.3e-03 nm, Epot= -8.06421e+03 Fmax= 9.24652e+02, atom= 1337
# Step=  407, Dmax= 2.8e-03 nm, Epot= -8.06698e+03 Fmax= 9.02142e+02, atom= 1337
# Step=  408, Dmax= 3.4e-03 nm, Epot= -8.06844e+03 Fmax= 1.36719e+03, atom= 1337
# Step=  409, Dmax= 4.1e-03 nm, Epot= -8.07144e+03 Fmax= 1.27621e+03, atom= 1337
# Step=  411, Dmax= 2.4e-03 nm, Epot= -8.07634e+03 Fmax= 3.42532e+02, atom= 1337
# Step=  412, Dmax= 2.9e-03 nm, Epot= -8.07954e+03 Fmax= 1.49697e+03, atom= 1337
# Step=  413, Dmax= 3.5e-03 nm, Epot= -8.08500e+03 Fmax= 8.33591e+02, atom= 1337
# Step=  415, Dmax= 2.1e-03 nm, Epot= -8.08801e+03 Fmax= 5.30712e+02, atom= 1337
# Step=  416, Dmax= 2.5e-03 nm, Epot= -8.09006e+03 Fmax= 1.17934e+03, atom= 1337
# Step=  417, Dmax= 3.0e-03 nm, Epot= -8.09378e+03 Fmax= 7.94260e+02, atom= 1337
# Step=  419, Dmax= 1.8e-03 nm, Epot= -8.09680e+03 Fmax= 4.22977e+02, atom= 1337
# Step=  420, Dmax= 2.2e-03 nm, Epot= -8.09966e+03 Fmax= 9.65508e+02, atom= 1337
# Step=  421, Dmax= 2.6e-03 nm, Epot= -8.10280e+03 Fmax= 7.83669e+02, atom= 1337
# Step=  422, Dmax= 3.1e-03 nm, Epot= -8.10417e+03 Fmax= 1.24591e+03, atom= 1337
# Step=  423, Dmax= 3.8e-03 nm, Epot= -8.10683e+03 Fmax= 1.26708e+03, atom= 1337
# Step=  424, Dmax= 4.5e-03 nm, Epot= -8.10713e+03 Fmax= 1.67426e+03, atom= 1337
# Step=  425, Dmax= 5.4e-03 nm, Epot= -8.10818e+03 Fmax= 1.93817e+03, atom= 1337
# Step=  427, Dmax= 3.3e-03 nm, Epot= -8.11734e+03 Fmax= 2.03979e+02, atom= 1337
# Step=  463, Dmax= 2.1e-03 nm, Epot= -8.20949e+03 Fmax= 2.25638e+02, atom= 1337
# Step=  464, Dmax= 2.5e-03 nm, Epot= -8.21276e+03 Fmax= 1.50461e+03, atom= 1337
# Step=  465, Dmax= 3.0e-03 nm, Epot= -8.21875e+03 Fmax= 4.75748e+02, atom= 1337
# Step=  467, Dmax= 1.8e-03 nm, Epot= -8.22082e+03 Fmax= 7.42659e+02, atom= 1337
# Step=  468, Dmax= 2.2e-03 nm, Epot= -8.22310e+03 Fmax= 6.70728e+02, atom= 1337
# Step=  469, Dmax= 2.6e-03 nm, Epot= -8.22437e+03 Fmax= 1.07510e+03, atom= 1337
# Step=  470, Dmax= 3.1e-03 nm, Epot= -8.22684e+03 Fmax= 9.67845e+02, atom= 1337
# Step=  472, Dmax= 1.9e-03 nm, Epot= -8.23029e+03 Fmax= 2.79345e+02, atom= 1337
# Step=  473, Dmax= 2.3e-03 nm, Epot= -8.23302e+03 Fmax= 1.15219e+03, atom= 1337
# Step=  474, Dmax= 2.7e-03 nm, Epot= -8.23692e+03 Fmax= 6.42627e+02, atom= 1337
# Step=  476, Dmax= 1.6e-03 nm, Epot= -8.23922e+03 Fmax= 4.12184e+02, atom= 1337
# Step=  477, Dmax= 1.9e-03 nm, Epot= -8.24108e+03 Fmax= 9.00122e+02, atom= 1337
# Step=  478, Dmax= 2.3e-03 nm, Epot= -8.24383e+03 Fmax= 6.24404e+02, atom= 1337
# Step=  479, Dmax= 2.8e-03 nm, Epot= -8.24423e+03 Fmax= 1.25344e+03, atom= 1337
# Step=  480, Dmax= 3.4e-03 nm, Epot= -8.24758e+03 Fmax= 9.47466e+02, atom= 1337
# Step=  482, Dmax= 2.0e-03 nm, Epot= -8.25089e+03 Fmax= 3.92911e+02, atom= 1337
# Step=  483, Dmax= 2.4e-03 nm, Epot= -8.25214e+03 Fmax= 1.16440e+03, atom= 1337
# Step=  484, Dmax= 2.9e-03 nm, Epot= -8.25582e+03 Fmax= 7.64156e+02, atom= 1337
# Step=  486, Dmax= 1.7e-03 nm, Epot= -8.25843e+03 Fmax= 3.73860e+02, atom= 1337
# Step=  487, Dmax= 2.1e-03 nm, Epot= -8.26000e+03 Fmax= 1.03762e+03, atom= 1337
# Step=  488, Dmax= 2.5e-03 nm, Epot= -8.26331e+03 Fmax= 6.04959e+02, atom= 1337
# Step=  490, Dmax= 1.5e-03 nm, Epot= -8.26554e+03 Fmax= 4.00806e+02, atom= 1337
# Step=  491, Dmax= 1.8e-03 nm, Epot= -8.26747e+03 Fmax= 7.64823e+02, atom= 1337
# Step=  492, Dmax= 2.2e-03 nm, Epot= -8.26975e+03 Fmax= 6.80384e+02, atom= 1337
# Step=  493, Dmax= 2.6e-03 nm, Epot= -8.27080e+03 Fmax= 1.01200e+03, atom= 1337
# Step=  494, Dmax= 3.1e-03 nm, Epot= -8.27268e+03 Fmax= 1.06504e+03, atom= 1337
# Step=  495, Dmax= 3.7e-03 nm, Epot= -8.27290e+03 Fmax= 1.38183e+03, atom= 1337
# Step=  496, Dmax= 4.5e-03 nm, Epot= -8.27352e+03 Fmax= 1.60510e+03, atom= 1337
# Step=  498, Dmax= 2.7e-03 nm, Epot= -8.28101e+03 Fmax= 1.72549e+02, atom= 1337
# Step=  499, Dmax= 3.2e-03 nm, Epot= -8.28282e+03 Fmax= 2.05104e+03, atom= 1337
# Step=  500, Dmax= 3.9e-03 nm, Epot= -8.29395e+03 Fmax= 5.08136e+02, atom= 1337
# Step=  502, Dmax= 2.3e-03 nm, Epot= -8.29477e+03 Fmax= 1.05486e+03, atom= 1337
# Step=  503, Dmax= 2.8e-03 nm, Epot= -8.29769e+03 Fmax= 7.76293e+02, atom= 1337
# Step=  505, Dmax= 1.7e-03 nm, Epot= -8.30037e+03 Fmax= 3.39375e+02, atom= 1337
# Step=  506, Dmax= 2.0e-03 nm, Epot= -8.30200e+03 Fmax= 9.57406e+02, atom= 1337
# Step=  507, Dmax= 2.4e-03 nm, Epot= -8.30497e+03 Fmax= 6.47303e+02, atom= 1337
# Step=  509, Dmax= 1.4e-03 nm, Epot= -8.30722e+03 Fmax= 2.99481e+02, atom= 1337
# Step=  510, Dmax= 1.7e-03 nm, Epot= -8.30914e+03 Fmax= 8.75194e+02, atom= 1337
# Step=  511, Dmax= 2.1e-03 nm, Epot= -8.31196e+03 Fmax= 4.91392e+02, atom= 1337
# Step=  512, Dmax= 2.5e-03 nm, Epot= -8.31210e+03 Fmax= 1.18742e+03, atom= 1337
# Step=  513, Dmax= 3.0e-03 nm, Epot= -8.31570e+03 Fmax= 7.83996e+02, atom= 1337
# Step=  515, Dmax= 1.8e-03 nm, Epot= -8.31837e+03 Fmax= 4.14374e+02, atom= 1337
# Step=  516, Dmax= 2.2e-03 nm, Epot= -8.31936e+03 Fmax= 9.87249e+02, atom= 1337
# Step=  517, Dmax= 2.6e-03 nm, Epot= -8.32223e+03 Fmax= 7.36715e+02, atom= 1337
# Step=  519, Dmax= 1.6e-03 nm, Epot= -8.32475e+03 Fmax= 2.83391e+02, atom= 1337
# Step=  520, Dmax= 1.9e-03 nm, Epot= -8.32643e+03 Fmax= 9.78716e+02, atom= 1337
# Step=  521, Dmax= 2.2e-03 nm, Epot= -8.32973e+03 Fmax= 4.92563e+02, atom= 1337
# Step=  523, Dmax= 1.3e-03 nm, Epot= -8.33164e+03 Fmax= 4.06434e+02, atom= 1337
# Step=  524, Dmax= 1.6e-03 nm, Epot= -8.33332e+03 Fmax= 6.41443e+02, atom= 1337
# Step=  525, Dmax= 1.9e-03 nm, Epot= -8.33516e+03 Fmax= 6.50029e+02, atom= 1337
# Step=  526, Dmax= 2.3e-03 nm, Epot= -8.33631e+03 Fmax= 8.67444e+02, atom= 1337
# Step=  527, Dmax= 2.8e-03 nm, Epot= -8.33767e+03 Fmax= 9.88575e+02, atom= 1337
# Step=  528, Dmax= 3.4e-03 nm, Epot= -8.33823e+03 Fmax= 1.20316e+03, atom= 1337
# Step=  529, Dmax= 4.0e-03 nm, Epot= -8.33835e+03 Fmax= 1.46595e+03, atom= 1337
# Step=  531, Dmax= 2.4e-03 nm, Epot= -8.34536e+03 Fmax= 1.29138e+02, atom= 1262
# Step=  532, Dmax= 2.9e-03 nm, Epot= -8.34940e+03 Fmax= 1.82426e+03, atom= 1262
# Step=  533, Dmax= 3.5e-03 nm, Epot= -8.35913e+03 Fmax= 4.73150e+02, atom= 1262
# Step=  535, Dmax= 2.1e-03 nm, Epot= -8.36001e+03 Fmax= 9.16685e+02, atom= 1262
# Step=  536, Dmax= 2.5e-03 nm, Epot= -8.36241e+03 Fmax= 7.30359e+02, atom= 1262
# Step=  538, Dmax= 1.5e-03 nm, Epot= -8.36489e+03 Fmax= 2.64336e+02, atom= 1262
# Step=  539, Dmax= 1.8e-03 nm, Epot= -8.36670e+03 Fmax= 9.10156e+02, atom= 1262
# Step=  540, Dmax= 2.2e-03 nm, Epot= -8.36961e+03 Fmax= 5.21904e+02, atom= 1262
# Step=  542, Dmax= 1.3e-03 nm, Epot= -8.37145e+03 Fmax= 3.30722e+02, atom= 1262
# Step=  543, Dmax= 1.6e-03 nm, Epot= -8.37309e+03 Fmax= 7.07497e+02, atom= 1262
# Step=  544, Dmax= 1.9e-03 nm, Epot= -8.37519e+03 Fmax= 5.21513e+02, atom= 1262
# Step=  545, Dmax= 2.2e-03 nm, Epot= -8.37588e+03 Fmax= 9.70016e+02, atom= 1262
# Step=  546, Dmax= 2.7e-03 nm, Epot= -8.37819e+03 Fmax= 8.01133e+02, atom= 1262
# Step=  548, Dmax= 1.6e-03 nm, Epot= -8.38085e+03 Fmax= 2.67166e+02, atom= 1262
# Step=  549, Dmax= 1.9e-03 nm, Epot= -8.38246e+03 Fmax= 9.96315e+02, atom= 1262
# Step=  550, Dmax= 2.3e-03 nm, Epot= -8.38563e+03 Fmax= 5.42171e+02, atom= 1262
# Step=  552, Dmax= 1.4e-03 nm, Epot= -8.38744e+03 Fmax= 3.74676e+02, atom= 1262
# Step=  553, Dmax= 1.7e-03 nm, Epot= -8.38888e+03 Fmax= 7.39949e+02, atom= 1262
# Step=  554, Dmax= 2.0e-03 nm, Epot= -8.39089e+03 Fmax= 5.81472e+02, atom= 1262
# Step=  555, Dmax= 2.4e-03 nm, Epot= -8.39142e+03 Fmax= 1.02058e+03, atom= 1262
# Step=  556, Dmax= 2.9e-03 nm, Epot= -8.39360e+03 Fmax= 8.83406e+02, atom= 1262
# Step=  558, Dmax= 1.7e-03 nm, Epot= -8.39650e+03 Fmax= 2.64102e+02, atom= 1262
# Step=  559, Dmax= 2.1e-03 nm, Epot= -8.39791e+03 Fmax= 1.09432e+03, atom= 1262
# Step=  560, Dmax= 2.5e-03 nm, Epot= -8.40144e+03 Fmax= 5.58552e+02, atom= 1262
# Step=  562, Dmax= 1.5e-03 nm, Epot= -8.40320e+03 Fmax= 4.27241e+02, atom= 1262
# Step=  563, Dmax= 1.8e-03 nm, Epot= -8.40447e+03 Fmax= 7.69491e+02, atom= 1262
# Step=  564, Dmax= 2.2e-03 nm, Epot= -8.40638e+03 Fmax= 6.51031e+02, atom= 1262
# Step=  565, Dmax= 2.6e-03 nm, Epot= -8.40676e+03 Fmax= 1.06989e+03, atom= 1262
# Step=  566, Dmax= 3.1e-03 nm, Epot= -8.40875e+03 Fmax= 9.76782e+02, atom= 1262
# Step=  568, Dmax= 1.9e-03 nm, Epot= -8.41198e+03 Fmax= 2.55909e+02, atom= 1262
# Step=  569, Dmax= 2.2e-03 nm, Epot= -8.41320e+03 Fmax= 1.20432e+03, atom= 1262
# Step=  570, Dmax= 2.7e-03 nm, Epot= -8.41717e+03 Fmax= 5.71568e+02, atom= 1262
# Step=  572, Dmax= 1.6e-03 nm, Epot= -8.41886e+03 Fmax= 4.88207e+02, atom= 1262
# Step=  573, Dmax= 1.9e-03 nm, Epot= -8.42000e+03 Fmax= 7.96947e+02, atom= 1262
# Step=  574, Dmax= 2.3e-03 nm, Epot= -8.42175e+03 Fmax= 7.30144e+02, atom= 1262
# Step=  575, Dmax= 2.8e-03 nm, Epot= -8.42207e+03 Fmax= 1.11871e+03, atom= 1262
# Step=  576, Dmax= 3.3e-03 nm, Epot= -8.42378e+03 Fmax= 1.08124e+03, atom= 1262
# Step=  578, Dmax= 2.0e-03 nm, Epot= -8.42742e+03 Fmax= 2.42850e+02, atom= 1262
# Step=  579, Dmax= 2.4e-03 nm, Epot= -8.42846e+03 Fmax= 1.32647e+03, atom= 1262
# Step=  580, Dmax= 2.9e-03 nm, Epot= -8.43301e+03 Fmax= 5.81442e+02, atom= 1262
# Step=  582, Dmax= 1.7e-03 nm, Epot= -8.43459e+03 Fmax= 5.57768e+02, atom= 1262
# Step=  583, Dmax= 2.1e-03 nm, Epot= -8.43567e+03 Fmax= 8.22597e+02, atom= 1262
# Step=  584, Dmax= 2.5e-03 nm, Epot= -8.43721e+03 Fmax= 8.18878e+02, atom= 1262
# Step=  585, Dmax= 3.0e-03 nm, Epot= -8.43750e+03 Fmax= 1.16733e+03, atom= 1262
# Step=  586, Dmax= 3.6e-03 nm, Epot= -8.43884e+03 Fmax= 1.19721e+03, atom= 1262
# Step=  588, Dmax= 2.2e-03 nm, Epot= -8.44301e+03 Fmax= 2.25140e+02, atom= 1262
# Step=  589, Dmax= 2.6e-03 nm, Epot= -8.44392e+03 Fmax= 1.46136e+03, atom= 1262
# Step=  590, Dmax= 3.1e-03 nm, Epot= -8.44918e+03 Fmax= 5.88577e+02, atom= 1262
# Step=  592, Dmax= 1.9e-03 nm, Epot= -8.45062e+03 Fmax= 6.35816e+02, atom= 1262
# Step=  593, Dmax= 2.2e-03 nm, Epot= -8.45168e+03 Fmax= 8.46892e+02, atom= 1262
# Step=  594, Dmax= 2.7e-03 nm, Epot= -8.45295e+03 Fmax= 9.17433e+02, atom= 1262
# Step=  595, Dmax= 3.2e-03 nm, Epot= -8.45328e+03 Fmax= 1.21660e+03, atom= 1262
# Step=  596, Dmax= 3.9e-03 nm, Epot= -8.45418e+03 Fmax= 1.32471e+03, atom= 1262
# Step=  598, Dmax= 2.3e-03 nm, Epot= -8.45896e+03 Fmax= 2.03066e+02, atom= 1262
# Step=  599, Dmax= 2.8e-03 nm, Epot= -8.45985e+03 Fmax= 1.60901e+03, atom= 1262
# Step=  600, Dmax= 3.3e-03 nm, Epot= -8.46599e+03 Fmax= 5.93599e+02, atom= 1262
# Step=  602, Dmax= 2.0e-03 nm, Epot= -8.46724e+03 Fmax= 7.22135e+02, atom= 1262
# Step=  603, Dmax= 2.4e-03 nm, Epot= -8.46835e+03 Fmax= 8.70735e+02, atom= 1262
# Step=  604, Dmax= 2.9e-03 nm, Epot= -8.46926e+03 Fmax= 1.02549e+03, atom= 1262
# Step=  605, Dmax= 3.5e-03 nm, Epot= -8.46971e+03 Fmax= 1.26747e+03, atom= 1262
# Step=  606, Dmax= 4.1e-03 nm, Epot= -8.47002e+03 Fmax= 1.46375e+03, atom= 1262
# Step=  608, Dmax= 2.5e-03 nm, Epot= -8.47557e+03 Fmax= 1.77378e+02, atom= 1262
# Step=  609, Dmax= 3.0e-03 nm, Epot= -8.47664e+03 Fmax= 1.76955e+03, atom= 1262
# Step=  610, Dmax= 3.6e-03 nm, Epot= -8.48386e+03 Fmax= 5.97105e+02, atom= 1262
# Step=  612, Dmax= 2.2e-03 nm, Epot= -8.48486e+03 Fmax= 8.16542e+02, atom= 1262
# Step=  613, Dmax= 2.6e-03 nm, Epot= -8.48609e+03 Fmax= 8.94909e+02, atom= 1262
# Step=  614, Dmax= 3.1e-03 nm, Epot= -8.48655e+03 Fmax= 1.14284e+03, atom= 1262
# Step=  615, Dmax= 3.7e-03 nm, Epot= -8.48718e+03 Fmax= 1.32107e+03, atom= 1262
# Step=  617, Dmax= 2.2e-03 nm, Epot= -8.49172e+03 Fmax= 1.54541e+02, atom= 1262
# Step=  618, Dmax= 2.7e-03 nm, Epot= -8.49418e+03 Fmax= 1.63836e+03, atom= 1262
# Step=  619, Dmax= 3.2e-03 nm, Epot= -8.50023e+03 Fmax= 4.84542e+02, atom= 1262
# Step=  621, Dmax= 1.9e-03 nm, Epot= -8.50124e+03 Fmax= 7.96132e+02, atom= 1262
# Step=  622, Dmax= 2.3e-03 nm, Epot= -8.50277e+03 Fmax= 7.26393e+02, atom= 1262
# Step=  623, Dmax= 2.8e-03 nm, Epot= -8.50306e+03 Fmax= 1.11543e+03, atom= 1262
# Step=  624, Dmax= 3.3e-03 nm, Epot= -8.50456e+03 Fmax= 1.07779e+03, atom= 1262
# Step=  626, Dmax= 2.0e-03 nm, Epot= -8.50771e+03 Fmax= 2.41401e+02, atom= 1262
# Step=  627, Dmax= 2.4e-03 nm, Epot= -8.50867e+03 Fmax= 1.32517e+03, atom= 1262
# Step=  628, Dmax= 2.9e-03 nm, Epot= -8.51264e+03 Fmax= 5.75752e+02, atom= 1262
# Step=  630, Dmax= 1.7e-03 nm, Epot= -8.51402e+03 Fmax= 5.60297e+02, atom= 1262
# Step=  631, Dmax= 2.1e-03 nm, Epot= -8.51498e+03 Fmax= 8.14384e+02, atom= 1262
# Step=  632, Dmax= 2.5e-03 nm, Epot= -8.51629e+03 Fmax= 8.22312e+02, atom= 1262
# Step=  633, Dmax= 3.0e-03 nm, Epot= -8.51660e+03 Fmax= 1.15625e+03, atom= 1262
# Step=  634, Dmax= 3.6e-03 nm, Epot= -8.51773e+03 Fmax= 1.20104e+03, atom= 1262
# Step=  636, Dmax= 2.1e-03 nm, Epot= -8.52140e+03 Fmax= 2.15945e+02, atom= 1262
# Step=  637, Dmax= 2.6e-03 nm, Epot= -8.52233e+03 Fmax= 1.46753e+03, atom= 1262
# Step=  638, Dmax= 3.1e-03 nm, Epot= -8.52705e+03 Fmax= 5.74867e+02, atom= 1262
# Step=  640, Dmax= 1.9e-03 nm, Epot= -8.52827e+03 Fmax= 6.46023e+02, atom= 1262
# Step=  641, Dmax= 2.2e-03 nm, Epot= -8.52925e+03 Fmax= 8.30711e+02, atom= 1262
# Step=  642, Dmax= 2.7e-03 nm, Epot= -8.53028e+03 Fmax= 9.28246e+02, atom= 1262
# Step=  643, Dmax= 3.2e-03 nm, Epot= -8.53068e+03 Fmax= 1.19752e+03, atom= 1262
# Step=  644, Dmax= 3.8e-03 nm, Epot= -8.53132e+03 Fmax= 1.33585e+03, atom= 1262
# Step=  646, Dmax= 2.3e-03 nm, Epot= -8.53563e+03 Fmax= 1.86252e+02, atom= 1262
# Step=  647, Dmax= 2.8e-03 nm, Epot= -8.53675e+03 Fmax= 1.62226e+03, atom= 1262
# Step=  648, Dmax= 3.3e-03 nm, Epot= -8.54236e+03 Fmax= 5.72251e+02, atom= 1262
# Step=  650, Dmax= 2.0e-03 nm, Epot= -8.54339e+03 Fmax= 7.39473e+02, atom= 1262
# Step=  651, Dmax= 2.4e-03 nm, Epot= -8.54446e+03 Fmax= 8.47141e+02, atom= 1262
# Step=  652, Dmax= 2.9e-03 nm, Epot= -8.54513e+03 Fmax= 1.04309e+03, atom= 1262
# Step=  653, Dmax= 3.4e-03 nm, Epot= -8.54567e+03 Fmax= 1.24105e+03, atom= 1262
# Step=  654, Dmax= 4.1e-03 nm, Epot= -8.54572e+03 Fmax= 1.48124e+03, atom= 1262
# Step=  656, Dmax= 2.5e-03 nm, Epot= -8.55082e+03 Fmax= 1.53744e+02, atom= 1262
# Step=  657, Dmax= 3.0e-03 nm, Epot= -8.55248e+03 Fmax= 1.78877e+03, atom= 1262
# Step=  658, Dmax= 3.6e-03 nm, Epot= -8.55922e+03 Fmax= 5.69448e+02, atom= 1262
# Step=  660, Dmax= 2.1e-03 nm, Epot= -8.56000e+03 Fmax= 8.39438e+02, atom= 1262
# Step=  661, Dmax= 2.6e-03 nm, Epot= -8.56121e+03 Fmax= 8.65421e+02, atom= 1262
# Step=  662, Dmax= 3.1e-03 nm, Epot= -8.56142e+03 Fmax= 1.16572e+03, atom= 1262
# Step=  663, Dmax= 3.7e-03 nm, Epot= -8.56218e+03 Fmax= 1.28877e+03, atom= 1262
# Step=  665, Dmax= 2.2e-03 nm, Epot= -8.56615e+03 Fmax= 1.81930e+02, atom= 1262
# Step=  666, Dmax= 2.7e-03 nm, Epot= -8.56728e+03 Fmax= 1.59977e+03, atom= 1262
# Step=  667, Dmax= 3.2e-03 nm, Epot= -8.57254e+03 Fmax= 5.16231e+02, atom= 1262
# GROMACS reminds you: "If you want to destroy my sweater, hold this thread as I walk away." (Weezer)
# (0, None, None)

# %%
# NvT equilibrate the system

def write_gromacs_nvt_equil_mdp_for_chloroform(filename):
    ''' writes a gromacs mdp file for equilibration'''
    with open(filename, 'w') as f:
        f.write(f'''define                 = -DPOSRE          ; position restrain the protein
; Run parameters
integrator             = md                          ; leap-frog integrator
nsteps                 = 100000                      ; 2 * 100000 = 200 ps
dt                     = 0.002                       ; 2 fs
; Output control
nstxout                = 1000                        ; save coordinates every 2 ps
nstvout                = 1000                        ; save velocities every 2 ps
nstenergy              = 1000                        ; save energies every 2 ps
nstlog                 = 1000                        ; update log file every 2 ps
; Bond parameters
continuation           = no                          ; Initial simulation
constraint_algorithm   = lincs                       ; holonomic constraints
constraints            = h-bonds                     ; all bonds (even heavy atom-H bonds) constrained
lincs_iter             = 1                           ; accuracy of LINCS
lincs_order            = 4                           ; also related to accuracy
; Neighborsearching
ns_type                = grid                        ; search neighboring grid cels
nstlist                = 10                          ; 20 fs
rlist                  = 1.4                         ; short-range neighborlist cutoff (in nm)
rcoulomb               = 1.4                         ; short-range electrostatic cutoff (in nm)
rvdw                   = 1.4                         ; short-range van der Waals cutoff (in nm)
; Electrostatics
coulombtype            = PME                         ; Particle Mesh Ewald for long-range electrostatics
pme_order              = 4                           ; cubic interpolation
fourierspacing         = 0.16                        ; grid spacing for FFT
; Temperature coupling is on
tcoupl                 = V-rescale                   ; Weak coupling for initial equilibration
tc-grps                = System                      ; two coupling groups - more accurate
tau_t                  = 0.1                         ; time constant, in ps
ref_t                  = 298.15                      ; reference temperature, one for each group, in K
; Pressure coupling is on
pcoupl                 = Berendsen                   ; Pressure coupling on in NPT, also weak coupling
pcoupltype             = isotropic                   ; uniform scaling of x-y-z box vectors
tau_p                  = 2.0                         ; time constant, in ps
ref_p                  = 1.0                         ; reference pressure (in bar)
compressibility        = 4.5e-5                      ; isothermal compressibility, bar^-1
refcoord_scaling       = com
; Periodic boundary conditions
pbc                    = xyz                         ; 3-D PBC
; Dispersion correction
DispCorr               = EnerPres                    ; account for cut-off vdW scheme
; Velocity generationd
gen_vel                = yes                         ; Velocity generation is on
gen_temp               = 298.15                      ; temperature for velocity generation
gen_seed               = -1                          ; random seed
; These options remove COM motion of the system
nstcomm                = 10
comm-mode              = Linear
comm-grps              = System''')
    f.close()

# %%
## Equilibrate the system
nvt_mdpfile = f'{workdir}/nvt.mdp'
write_gromacs_nvt_equil_mdp_for_chloroform(nvt_mdpfile)

nvt_tprfile = f'{workdir}/nvt.tpr'
nvt_grofile = f'{workdir}/nvt.gro'
nvt_logfile = f'{workdir}/nvt.log'
nvt_xtcfile = f'{workdir}/nvt.xtc'
nvt_trrfile = f'{workdir}/nvt.trr'
nvt_edrfile = f'{workdir}/nvt.edr'
nvt_cptfile = f'{workdir}/nvt.cpt'

gromacs.grompp(f=nvt_mdpfile, c=em_grofile, p=input_topfile, o=nvt_tprfile, maxwarn=1)
gromacs.mdrun(v=True, s=nvt_tprfile, o=nvt_trrfile, x=nvt_xtcfile,
              c=nvt_grofile, e=nvt_edrfile, g=nvt_logfile, cpo=nvt_cptfile)
# Out:
#                       :-) GROMACS - gmx grompp, 2020.4 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx grompp, version 2020.4
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/sgoold/git_repo/sampl9-voelzlab/logP/GAFF/solvent_boxes/chloroform
# Command line:
#   gmx grompp -f ./work/nvt.mdp -c ./work/em.gro -p chloroform_GMX.top -o ./work/nvt.tpr -maxwarn 1
#
# Ignoring obsolete mdp entry 'ns_type'
#
# NOTE 1 [file ./work/nvt.mdp]:
#   nstcomm < nstcalcenergy defeats the purpose of nstcalcenergy, setting
#   nstcomm to nstcalcenergy
#
# Setting the LD random seed to -1449502701
# Generated 6 of the 6 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 0.5
# Generated 6 of the 6 1-4 parameter combinations
# Excluding 3 bonded neighbours molecule type 'CHL'
#
# WARNING 1 [file chloroform_GMX.top, line 47]:
#   The following macros were defined in the 'define' mdp field with the -D
#   prefix, but were not used in the topology:
#       POSRE
#   If you haven't made a spelling error, either use the macro you defined,
#   or don't define the macro
#
# Setting gen_seed to -715230156
# Velocities were taken from a Maxwell distribution at 298.15 K
# Number of degrees of freedom in T-Coupling group System is 4477.00
# Estimate for the relative computational load of the PME mesh part: 0.24
#
# There was 1 note
#
# There was 1 warning
#
# GROMACS reminds you: "Above all, don't fear difficult moments. The best comes from them." (Rita Levi-Montalcini)
#
#                       :-) GROMACS - gmx mdrun, 2020.4 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx mdrun, version 2020.4
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/sgoold/git_repo/sampl9-voelzlab/logP/GAFF/solvent_boxes/chloroform
# Command line:
#   gmx mdrun -v -s ./work/nvt.tpr -o ./work/nvt.trr -x ./work/nvt.xtc -c ./work/nvt.gro -e ./work/nvt.edr -g ./work/nvt.log -cpo ./work/nvt.cpt
#
# Reading file ./work/nvt.tpr, VERSION 2020.4 (single precision)
# Changing nstlist from 10 to 100, rlist from 1.4 to 1.4
#
# 1 GPU selected for this run.
# Mapping of GPU IDs to the 2 GPU tasks in the 1 rank on this node:
#   PP:0,PME:0
# PP tasks will do (non-perturbed) short-ranged interactions on the GPU
# PP task will update and constrain coordinates on the CPU
# PME tasks will do all aspects on the GPU
# Using 1 MPI thread
#
# Non-default thread affinity set, disabling internal thread affinity
#
# Using 4 OpenMP threads
# turning H bonds into constraints...
# Analysing residue names:
# There are:   320      Other residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 298.15 K
# Calculated rlist for 1x1 atom pair-list as 1.400 nm, buffer size 0.000 nm
# Set rlist, assuming 4x4 atom pair-list, to 1.400 nm, buffer size 0.000 nm
# Note that mdrun will redetermine rlist based on the actual pair-list setup
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 24x24x24, spacing 0.146 0.146 0.146
# This run will generate roughly 4 Mb of data
# starting mdrun 'chloroform'
# 100000 steps,    200.0 ps.
# step 23300: timed with pme grid 24 24 24, coulomb cutoff 1.400: 57.3 M-cycles
# step 23300: the box size limits the PME load balancing to a coulomb cut-off of 1.531
# step 23500: timed with pme grid 20 20 20, coulomb cutoff 1.531: 69.0 M-cycles
# step 23700: timed with pme grid 24 24 24, coulomb cutoff 1.400: 56.6 M-cycles
#               optimal pme grid 24 24 24, coulomb cutoff 1.400
# step 99900, remaining wall clock time:     0 s
# Writing final coordinates.
# step 100000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:      134.429       33.607      400.0
#                  (ns/day)    (hour/ns)
# Performance:      514.178        0.047
#
# GROMACS reminds you: "Clickety Clickety Click" (System Manager From Hell)
# (0, None, None)

# %%
def write_gromacs_npt_equil_mdp_for_chloroform(filename):
    ''' writes a gromacs mdp file for equilibration'''
    with open(filename, 'w') as f:
        f.write(f'''define                 = -DPOSRE          ; position restrain the protein
; Run parameters
integrator             = md                          ; leap-frog integrator
nsteps                 = 100000                      ; 2 * 100000 = 200 ps
dt                     = 0.002                       ; 2 fs
; Output control
nstxout                = 1000                        ; save coordinates every 2 ps
nstvout                = 1000                        ; save velocities every 2 ps
nstenergy              = 1000                        ; save energies every 2 ps
nstlog                 = 1000                        ; update log file every 2 ps
; Bond parameters
continuation           = no                          ; Initial simulation
constraint_algorithm   = lincs                       ; holonomic constraints
constraints            = h-bonds                     ; all bonds (even heavy atom-H bonds) constrained
lincs_iter             = 1                           ; accuracy of LINCS
lincs_order            = 4                           ; also related to accuracy
; Neighborsearching
ns_type                = grid                        ; search neighboring grid cels
nstlist                = 10                          ; 20 fs
rlist                  = 1.4                         ; short-range neighborlist cutoff (in nm)
rcoulomb               = 1.4                         ; short-range electrostatic cutoff (in nm)
rvdw                   = 1.4                         ; short-range van der Waals cutoff (in nm)
; Electrostatics
coulombtype            = PME                         ; Particle Mesh Ewald for long-range electrostatics
pme_order              = 4                           ; cubic interpolation
fourierspacing         = 0.16                        ; grid spacing for FFT
; Temperature coupling is on
tcoupl                 = V-rescale                   ; Weak coupling for initial equilibration
tc-grps                = System                      ; two coupling groups - more accurate
tau_t                  = 0.1                         ; time constant, in ps
ref_t                  = 298.15                      ; reference temperature, one for each group, in K
; Pressure coupling is on
pcoupl                 = Berendsen                   ; Pressure coupling on in NPT, also weak coupling
pcoupltype             = isotropic                   ; uniform scaling of x-y-z box vectors
tau_p                  = 2.0                         ; time constant, in ps
ref_p                  = 1.0                         ; reference pressure (in bar)
compressibility        = 4.5e-5                      ; isothermal compressibility, bar^-1
refcoord_scaling       = com
; Periodic boundary conditions
pbc                    = xyz                         ; 3-D PBC
; Dispersion correction
DispCorr               = EnerPres                    ; account for cut-off vdW scheme
; Velocity generationd
gen_vel                = yes                         ; Velocity generation is on
gen_temp               = 298.15                      ; temperature for velocity generation
gen_seed               = -1                          ; random seed
; These options remove COM motion of the system
nstcomm                = 10
comm-mode              = Linear
comm-grps              = System''')
    f.close()

# %%
## Equilibrate the system
workdir = './work'
npt_mdpfile = f'{workdir}/npt.mdp'
write_gromacs_npt_equil_mdp_for_chloroform(npt_mdpfile)

nvt_tprfile = f'{workdir}/nvt.tpr'
nvt_grofile = f'{workdir}/nvt.gro'
nvt_logfile = f'{workdir}/nvt.log'
nvt_xtcfile = f'{workdir}/nvt.xtc'
nvt_trrfile = f'{workdir}/nvt.trr'
nvt_edrfile = f'{workdir}/nvt.edr'
nvt_cptfile = f'{workdir}/nvt.cpt'
input_topfile = 'chloroform_GMX.top'

npt_tprfile = f'{workdir}/npt.tpr'
npt_grofile = f'{workdir}/npt.gro'
npt_logfile = f'{workdir}/npt.log'
npt_xtcfile = f'{workdir}/npt.xtc'
npt_trrfile = f'{workdir}/npt.trr'
npt_edrfile = f'{workdir}/npt.edr'
npt_cptfile = f'{workdir}/npt.cpt'

gromacs.grompp(f=npt_mdpfile, c=nvt_grofile, p=input_topfile, o=npt_tprfile, maxwarn=1)
gromacs.mdrun(v=True, s=npt_tprfile, o=npt_trrfile, x=npt_xtcfile,
              c=npt_grofile, e=npt_edrfile, g=npt_logfile, cpo=npt_cptfile)
# Out:
#                       :-) GROMACS - gmx grompp, 2020.4 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx grompp, version 2020.4
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/sgoold/git_repo/sampl9-voelzlab/logP/GAFF/solvent_boxes/chloroform
# Command line:
#   gmx grompp -f ./work/npt.mdp -c ./work/nvt.gro -p chloroform_GMX.top -o ./work/npt.tpr -maxwarn 1
#
# Ignoring obsolete mdp entry 'ns_type'
#
# NOTE 1 [file ./work/npt.mdp]:
#   nstcomm < nstcalcenergy defeats the purpose of nstcalcenergy, setting
#   nstcomm to nstcalcenergy
#
# Setting the LD random seed to -71962783
# Generated 6 of the 6 non-bonded parameter combinations
# Generating 1-4 interactions: fudge = 0.5
# Generated 6 of the 6 1-4 parameter combinations
# Excluding 3 bonded neighbours molecule type 'CHL'
#
# WARNING 1 [file chloroform_GMX.top, line 47]:
#   The following macros were defined in the 'define' mdp field with the -D
#   prefix, but were not used in the topology:
#       POSRE
#   If you haven't made a spelling error, either use the macro you defined,
#   or don't define the macro
#
# Setting gen_seed to 406317428
# Velocities were taken from a Maxwell distribution at 298.15 K
# Number of degrees of freedom in T-Coupling group System is 4477.00
# Estimate for the relative computational load of the PME mesh part: 0.24
#
# There was 1 note
#
# There was 1 warning
#
# GROMACS reminds you: "Today we're not going to optimize our CUDA code, cause that's just a rabbit hole of misery!" (Tim Warburton)
#
#                       :-) GROMACS - gmx mdrun, 2020.4 (-:
#
#                             GROMACS is written by:
#      Emile Apol      Rossen Apostolov      Paul Bauer     Herman J.C. Berendsen
#     Par Bjelkmar      Christian Blau   Viacheslav Bolnykh     Kevin Boyd
#  Aldert van Buuren   Rudi van Drunen     Anton Feenstra       Alan Gray
#   Gerrit Groenhof     Anca Hamuraru    Vincent Hindriksen  M. Eric Irrgang
#   Aleksei Iupinov   Christoph Junghans     Joe Jordan     Dimitrios Karkoulis
#     Peter Kasson        Jiri Kraus      Carsten Kutzner      Per Larsson
#   Justin A. Lemkul    Viveca Lindahl    Magnus Lundborg     Erik Marklund
#     Pascal Merz     Pieter Meulenhoff    Teemu Murtola       Szilard Pall
#     Sander Pronk      Roland Schulz      Michael Shirts    Alexey Shvetsov
#    Alfons Sijbers     Peter Tieleman      Jon Vincent      Teemu Virolainen
#  Christian Wennberg    Maarten Wolf      Artem Zhmurov
#                            and the project leaders:
#         Mark Abraham, Berk Hess, Erik Lindahl, and David van der Spoel
#
# Copyright (c) 1991-2000, University of Groningen, The Netherlands.
# Copyright (c) 2001-2019, The GROMACS development team at
# Uppsala University, Stockholm University and
# the Royal Institute of Technology, Sweden.
# check out http://www.gromacs.org for more information.
#
# GROMACS is free software; you can redistribute it and/or modify it
# under the terms of the GNU Lesser General Public License
# as published by the Free Software Foundation; either version 2.1
# of the License, or (at your option) any later version.
#
# GROMACS:      gmx mdrun, version 2020.4
# Executable:   /usr/local/gromacs/bin/gmx
# Data prefix:  /usr/local/gromacs
# Working dir:  /home/sgoold/git_repo/sampl9-voelzlab/logP/GAFF/solvent_boxes/chloroform
# Command line:
#   gmx mdrun -v -s ./work/npt.tpr -o ./work/npt.trr -x ./work/npt.xtc -c ./work/npt.gro -e ./work/npt.edr -g ./work/npt.log -cpo ./work/npt.cpt
#
# Reading file ./work/npt.tpr, VERSION 2020.4 (single precision)
# Changing nstlist from 10 to 100, rlist from 1.4 to 1.4
#
# 1 GPU selected for this run.
# Mapping of GPU IDs to the 2 GPU tasks in the 1 rank on this node:
#   PP:0,PME:0
# PP tasks will do (non-perturbed) short-ranged interactions on the GPU
# PP task will update and constrain coordinates on the CPU
# PME tasks will do all aspects on the GPU
# Using 1 MPI thread
#
# Non-default thread affinity set, disabling internal thread affinity
#
# Using 4 OpenMP threads
# turning H bonds into constraints...
# Analysing residue names:
# There are:   320      Other residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 298.15 K
# Calculated rlist for 1x1 atom pair-list as 1.400 nm, buffer size 0.000 nm
# Set rlist, assuming 4x4 atom pair-list, to 1.400 nm, buffer size 0.000 nm
# Note that mdrun will redetermine rlist based on the actual pair-list setup
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 24x24x24, spacing 0.148 0.148 0.148
# This run will generate roughly 4 Mb of data
# starting mdrun 'chloroform'
# 100000 steps,    200.0 ps.
# step 21200: timed with pme grid 24 24 24, coulomb cutoff 1.400: 37.8 M-cycles
# step 21200: the box size limits the PME load balancing to a coulomb cut-off of 1.551
# step 21400: timed with pme grid 20 20 20, coulomb cutoff 1.551: 217.9 M-cycles
# step 21600: timed with pme grid 24 24 24, coulomb cutoff 1.400: 49.4 M-cycles
#               optimal pme grid 24 24 24, coulomb cutoff 1.400
# step 99900, remaining wall clock time:     0 s
# Writing final coordinates.
# step 100000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:       89.880       22.470      400.0
#                  (ns/day)    (hour/ns)
# Performance:      769.026        0.031
#
# GROMACS reminds you: "Do not quench your inspiration and your imagination; do not become the slave of your model." (Vincent Van Gogh)
# (0, None, None)
